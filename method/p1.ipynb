# %% [markdown]
# #  @static method
#
# - It is used for utiliy function
# - It is either related to the class nor objects
# - It is use to store extra functionlatities
# - It is used as utility or helper function inside the class
# It does not take any mandority argument like cs,self to store class or object
# - static method is used to define the static method
