# %%
class company:
    cname ='jhony walfer'
    ceo = 'Tony stark'
    locaion ='Delhi'
    def __init__(self,name,sal,desig):
        self.name=name
        self.sal=sal
        self.desig=desig
    def display(self):
        print(f"Name : {self.name}")
        print(f"sal : {self.sal}")
        print(f"Designation : {self.desig}")
    def upraise(self):
        self.sal = int(input("Enter sal :"))
        print("sal:{self.sal}")

e1=company("ankit",5000,"tester")
e1.display()
e1.upraise()
# Out:
# Name : ankit
# sal : 5000
# Designation : tester
# sal:{self.sal}

# %%
#create a class school that contains school 4 class members and 4 school  members, and create objects methods to deisplay and  another method to update to change marks of a student which present having.
class school:
    sname="DPS"
    scode=236
    hname="Ajay Singh"
    location="Delhi"

    def _init_(self,name,Std,marks,grade):
        self.name=name
        self.Std=Std
        self.marks=marks
        self.grade=grade
    def display(self):
        print(f"Name : {self.name}")
        print(f"Standard : {self.Std}")
        print(f"Marks : {self.marks}")
        print(f"Grade : {self.grade}")
    def upmarks(self):
        self.marks=int(input("Enter the new marks : "))
        print("Marks updated successfully")
        print(f"New Marks : {self.marks}")

s1=school()
s1.name="Rohan"
s1.Std=10
s1.marks=85
s1.grade="A"

print("School And Student Details")
print(f"School Name : {school.sname}")
print(f"School Code : {school.scode}")
print(f"Head Name : {school.hname}")
print(f"Location : {school.location}")
s1.display()
s1.upmarks()
# Out:
# School And Student Details
# School Name : DPS
# School Code : 236
# Head Name : Ajay Singh
# Location : Delhi
# Name : Rohan
# Standard : 10
# Marks : 85
# Grade : A
# Marks updated successfully
# New Marks : 96

# %%
class school:
    sname="DPS"
    scode=236
    hname="Ajay Singh"
    location="Delhi"

    def __init__(self,name,Std,marks,grade):
        self.name=name
        self.Std=Std
        self.marks=marks
        self.grade=grade
    def display(self):
        print(f"Name : {self.name}")
        print(f"Standard : {self.Std}")
        print(f"Marks : {self.marks}")
        print(f"Grade : {self.grade}")
    def upmarks(self):
        self.marks=int(input("Enter the new marks : "))
        print("Marks updated successfully")
        print(f"New Marks : {self.marks}")
    @classmethod
    def c_display(cls):
        #print("School And Student Details")
        print(f"School Name : {school.sname}")
        print(f"School Code : {school.scode}")
        print(f"Head Name : {school.hname}")
        print(f"Location : {school.location}")
        print(f'{cls.sname}')

    @classmethod
    def ch_dname(cls):
        cls.dname=input("Enter one value :")
        print(f'updates answer: {cls.dname}')
s1=school("Ankit",'10th',91,"A+")
s1.c_display()
# Out:
# School Name : DPS
# School Code : 236
# Head Name : Ajay Singh
# Location : Delhi
# DPS

# %%
class Test_Yantra:
    CEO="Suyash singh"
    LOC="Delhi"
    Email="asdfghjkl@gmail.com"
    def __init__(self,name,EID,sal,dept):
        self.name=name
        self.EID=EID
        self.sal=sal
        self.dept=dept
class Qspider(Test_Yantra):
    Manager="akash singh"
    BranchHead="Shambhu sir"
    LOC="Noida"
    def __init__(self,name,EID,sal,dept,batches, subject,):
        super().__init__(name,EID,sal,dept)
        self.batches=batches
        self.subject=subject
e1=Qspider("Ankit",111,120000,"cse","morning","maths")
print(e1.name)
# Out:
# Ankit

# %%
class Test_Yantra:
    CEO="Suyash singh"
    LOC="Delhi"
    Email="asdfghjkl@gmail.com"
    def __init__(self,name,EID,sal,dept):
        self.name=name
        self.EID=EID
        self.sal=sal
        self.dept=dept
class Qspider(Test_Yantra):
    Manager="akash singh"
    BranchHead="Shambhu sir"
    LOC="Noida"
    def __init__(self,name,EID,sal,dept,batches, subject,):
        #super().__init__(name,EID,sal,dept)
        Test_Yantra.__init__(self,name,EID,sal,dept)
        self.batches=batches
        self.subject=subject
e1=Qspider("Ankit",111,120000,"cse","morning","maths")
print(e1.name)
print(e1.EID)
print(e1.sal)
print(e1.dept)
print(e1.batches)
print(e1.subject)
# Out:
# Ankit
# 111
# 120000
# cse
# morning
# maths

# %%
class school:
    sname="Anuj yadav"
    Address="New ashok"
    phno=4561237891
    def __init__(self,name,age,rollno,sid):
        self.name=name
        self.age=age
        self.rollno=rollno
        self.sid=sid
    def display(self):
        print(f"student name : {self.name}")
        print(f"Student age : {self.age}")
        print(f"student roll no : {self.rollno}")
        print(f"student id : {self.sid}")
class house(school):
    member="ankit verma"
    prize=123
    members=20
    def __init__(self,name,age,rollno,sid,position,area):
        super().__init__(name,age,rollno,sid)
        self.position=position
        self.area=area
    def display(self):
        super().display()
        print(f"Position : {self.position}")

s1=house("Ankit Verma",19,1,1,23,"lucknow")
s1.display()
# Out:
# student name : Ankit Verma
# Student age : 19
# student roll no : 1
# student id : 1
# Position : 23

# %%
# polymorphism -----------------------------------------

class school:
    sname="Aman"
    age=19
    def __init__(self,name,std):
        self.name=name
        self.std=std

    def display(self):
            print(f'Name: {self.name}')
            print(f'std: {self.std}')
    f=display
    @classmethod
    def display(cls):
         print(f'sname: {cls.sname}')
s1=school('rahul',12)
s1.display()
s1.f()
# Out:
# sname: Aman
# Name: rahul
# std: 12

# %%
# operator overloding-----------------


class Demo:
    def __init__(self,marks):
        self.marks=marks
    def __add__(self,other):
        return self.marks + other.marks
s1=Demo(3)
s2=Demo(6)
print(s1+s2)
# Out:
# 9

# %%
# wap to create a class arithmetic which help you to perform all the arithmetic opertion on user define object.

class arithmetic:
    def __init__(self,number):
        self.number=number
    def __add__(self,other):
       return self.number + other.number
    def __sub__(self,other):
       return self.number -  other.number
     
    def __mul__(self,other):
       return self.number * other.number
    
    def __truediv__(self,other):
       return self.number / other.number
    
    def __floordiv__(self,other):
       return self.number // other.number
    
    def __mod__(self,other):
       return self.number % other.number
    def __pow__(self,other):
       return self.number ** other.number
s1=arithmetic(4)
s2=arithmetic(2)
print(s1+s2)
print(s1-s2)
print(s1*s2)
print(s1%s2)
print(s1**s2)
print(s1/s2)
print(s1//s2)
# Out:
# 6
# 2
# 8
# 0
# 16
# 2.0
# 2

# %%
# write a program to phonepay login by entering the correct otp.

import random

otp = random.randint(1000,9999)
print("otp =",otp)

while True:
   l=int(input("Enter the otp:"))
   if l==otp:
        print("Login done")
        break
   else:
      print("not login")
# Out:
# otp = 6183
