# %% [markdown]
# #class in oops-
# 1) class is a blueprint which will store properties and functionalities
# ( A blueprint or template for creating objects)
#
# 2) We can also call properties as members and functionalities as method  these properties and functionalities belong to the objects.
