# %% [markdown]
# # Methods: function inside of a class is known as method.
#
# # There are three types of methods:
#
# 1. class method
# 2. object method/instance method
# 3. static method
#
# 1. class method:- It is use to access and modify the class properties.
#
# * classmethod decorator is use before  defining a class method.
#
# * Symbol: #classmethod
#
# * it take the cls first arguments
#
# * cls carries the address of the class or object.
#
# ** Syntax: **
# - class classname:
# - @classmethod
# - def func.name(cls)
# - SB
# - obj = classname()
# - classname func_name()
# - obj.func_name()

# %%
class Bank:
    bname = "BOB"
    loc = "Noida"
    Ifsc = 'BOB123B'
    bmanager = 'Mr.Ashvik'

    @classmethod
    def banks_details(cls):
        print(cls.bname)
        print(cls.loc)
        print(cls.Ifsc)
        print(cls.bmanager)

    @classmethod
    def change_loc(cls):
        cls.loc = input("Enter the new location :")
        print("Location is change successfully :")
        cls.banks_details()




c1 = Bank()
c2 = Bank()
Bank.change_loc()
# Out:
# Location is change successfully :
# BOB
# delhi
# BOB123B
# Mr.Ashvik

# %% [markdown]
# 2. object method/instance method:
#
# - It takes mandatory argument the shell.
#
# - self carries the address of object.
#
# - it is use to access and modify.

# %%
class Bank:
    bname = "BOB"
    loc = "Noida"
    Ifsc = 'BOB123B'
    bmanager = 'Mr.Ashvik'

    def _init_(self, name, addr, sal):
        self.name = name
        self.addr = add
        self.sal = sal
    @classmethod
    def banks_details(cls):
        print(cls.bname)
        print(cls.loc)
        print(cls.Ifsc)
        print(cls.bmanager)

    @classmethod
    def change_loc(cls):
        cls.loc = input("Enter the new location :")
        print("Location is change successfully :")
        cls.banks_details()


                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    
c1 = Bank()
c2 = Bank()
Bank.change_loc()
# Out:
# Location is change successfully :
# BOB
# delhi
# BOB123B
# Mr.Ashvik

# %%
class Student:
    # Class variable
    count = 0
    
    # Constructor (runs when object is created)
    def __init__(self, name, marks):
        self.name = name          # Instance variable
        self.marks = marks        # Instance variable
        Student.count += 1        # Increase count when a new object is created
    
    # Method to calculate grade
    def grade(self):
        if self.marks >= 90:
            return "A"
        elif self.marks >= 75:
            return "B"
        elif self.marks >= 60:
            return "C"
        else:
            return "D"


# Creating objects
s1 = Student("Ankit", 85)
s2 = Student("Rahul", 92)

# Printing details
print("Total Students:", Student.count)
print(s1.name, "Grade:", s1.grade())
# Out:
# Total Students: 2
# Ankit Grade: B

# %%
class Bank: # class name bank
    bname = "BOB"                # class variable
    loc = "Noida"
    ifsc = 'BOB123B'
    bmanager = 'Mr. Ashvik'

    def __init__(self, name, addr, bal):    # constructor method
        self.name = name
        self.addr = addr       # instance variable
        self.bal = bal

    @classmethod         #decorator class variable ko access krta hai
    def bank_details(cls):
        print("Bank Name:", cls.bname)     # bank ki common details ko print krta hai
        print("Location:", cls.loc)
        print("IFSC:", cls.ifsc)
        print("Manager:", cls.bmanager)

    def deposit(self):            #instance method
        amount = self.get_amount()      # user se amount inmput lega
        self.bal += amount         # balance me amount ko add krega
        print("Deposited successfully.")
        print(f"Available balance: {self.bal}")

    def withdraw(self):          # paisa nikalane ke liye method 
        amount = self.get_amount()         # user se withdrawal input
        if self.bal >= amount:     # check balance
            self.bal -= amount      
            print("Withdrawn successfully.")
            print(f"Available balance: {self.bal}")
        else:
            print("Insufficient balance")

    @staticmethod           #static method
    def get_amount():
        return int(input("Enter the amount: "))         # user se input lega 

    @classmethod
    def change_loc(cls):          # bank ka location change krta hai
        cls.loc = input("Enter the new location: ")     #Class variable loc update hota hai
        print("Location changed successfully")
        cls.bank_details()


# Object creation
c1 = Bank("Ankit", "Noida", 5000)
c2 = Bank("Rahul", "Delhi", 3000)

# c1.deposit() #Method Call
# c1.withdraw()
# c1.get_amount()
print("Enter---\n1 for bank info\n2 for customer info\n3 for deposite\n4 for withdraw\n5 for change address\n6 for exist")

    choice = int(input("Enter your choice--"))
    if choice == 1:
        c1.customer_details()
        print("="*40)
    elif choice == 2:
        c1.change_address()
        print("="*15)
    elif choice == 3:
        c1.deposite()
        print("="*15)
    elif choice == 4:
        c1.withdraw()
        print("="*15)
    elif choice == 5:
        print("Thank you")
        break
    else:
        print("Invalid choice")
        print("="*15)
# Out:
# Enter---
# 1 for bank info
# 2 for customer info
# 3 for deposite
# 4 for withdraw
# 5 for change address
# 6 for exist
